# %%
import pandas as pd

data_path = './data/cat-in-the-dat/'

train = pd.read_csv(data_path+'train.csv', index_col='id')
test = pd.read_csv(data_path+'test.csv', index_col='id')
submission = pd.read_csv(data_path+'sample_submission.csv', index_col='id')

# %%
train.shape
# Out:
# (300000, 24)

# %%
train.head()
# Out:
#     bin_0  bin_1  bin_2 bin_3 bin_4  ... ord_4 ord_5 day month target
# id                                   ...
# 0       0      0      0     T     Y  ...     D    kr   2     2      0
# 1       0      1      0     T     Y  ...     A    bF   7     8      0
# 2       0      0      0     F     Y  ...     R    Jc   7     2      0
# 3       0      1      0     F     Y  ...     D    kW   2     1      1
# 4       0      0      0     F     N  ...     R    qP   7     8      0
#
# [5 rows x 24 columns]

# %%
def resumetable(df):
    summary = pd.DataFrame(df.dtypes, columns=['데이터 타입'])
    summary = summary.reset_index()
    summary = summary.rename(columns={'intex': '피쳐'})
    summary['결측값 개수'] = df.isnull().sum().values
    summary['고유값 개수'] = df.nunique().values
    summary['첫번째 값'] = df.loc[0].values
    summary['두번째 값'] = df.loc[1].values

    return summary


resumetable(train)
# Out:
#      index  데이터 타입  결측값 개수  고유값 개수        첫번째 값        두번째 값
# 0    bin_0   int64       0       2            0            0
# 1    bin_1   int64       0       2            0            1
# 2    bin_2   int64       0       2            0            0
# 3    bin_3  object       0       2            T            T
# 4    bin_4  object       0       2            Y            Y
# 5    nom_0  object       0       3        Green        Green
# 6    nom_1  object       0       6     Triangle    Trapezoid
# 7    nom_2  object       0       6        Snake      Hamster
# 8    nom_3  object       0       6      Finland       Russia
# 9    nom_4  object       0       4      Bassoon        Piano
# 10   nom_5  object       0     222    50f116bcf    b3b4d25d0
# 11   nom_6  object       0     522    3ac1b8814    fbcb50fc1
# 12   nom_7  object       0    1220    68f6ad3e9    3b6dd5612
# 13   nom_8  object       0    2215    c389000ab    4cd920251
# 14   nom_9  object       0   11981    2f4cb3d51    f83c56c21
# 15   ord_0   int64       0       3            2            1
# 16   ord_1  object       0       5  Grandmaster  Grandmaster
# 17   ord_2  object       0       6         Cold          Hot
# 18   ord_3  object       0      15            h            a
# 19   ord_4  object       0      26            D            A
# 20   ord_5  object       0     192           kr           bF
# 21     day   int64       0       7            2            7
# 22   month   int64       0      12            2            8
# 23  target   int64       0       2            0            0

# %%
for i in range(3):
    feature = 'ord_' + str(i)
    print(f'{feature} 고유값 : {train[feature].unique()}')
# Out:
# ord_0 고유값 : [2 1 3]
# ord_1 고유값 : ['Grandmaster' 'Expert' 'Novice' 'Contributor' 'Master']
# ord_2 고유값 : ['Cold' 'Hot' 'Lava Hot' 'Boiling Hot' 'Freezing' 'Warm']

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ax = sns.countplot(x='target', data=train)
ax.set_title('target dist')
# Out:
# Text(0.5, 1.0, 'target dist')

# %%
import matplotlib.gridspec as gridspec
mpl.rc('font', size=12)
grid = gridspec.GridSpec(3, 2)
plt.figure(figsize=(10, 16))
plt.subplots_adjust(wspace=0.4, hspace=0.3)

bin_featrues = ['bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4', ]

for idx, feature in enumerate(bin_featrues):
    ax = plt.subplot(grid[idx])
    sns.countplot(x=feature, data=train, hue='target', palette='pastel', ax=ax)
    ax.set_title(f'{feature} Dist')
#     write_percent(ax, len(train))

# %%
all_data = pd.concat([train,test])
all_data = all_data.drop('target',axis=1)
all_data
# Out:
#         bin_0  bin_1  bin_2 bin_3 bin_4  ... ord_3 ord_4 ord_5 day month
# id                                       ...
# 0           0      0      0     T     Y  ...     h     D    kr   2     2
# 1           0      1      0     T     Y  ...     a     A    bF   7     8
# 2           0      0      0     F     Y  ...     h     R    Jc   7     2
# 3           0      1      0     F     Y  ...     i     D    kW   2     1
# 4           0      0      0     F     N  ...     a     R    qP   7     8
# ...       ...    ...    ...   ...   ...  ...   ...   ...   ...  ..   ...
# 499995      0      0      0     F     N  ...     j     A    Gb   1     3
# 499996      1      0      0     F     Y  ...     f     S    Ed   2     2
# 499997      0      1      1     T     Y  ...     g     V    TR   3     1
# 499998      1      0      0     T     Y  ...     g     X    Ye   2     1
# 499999      0      0      0     T     Y  ...     l     J    ex   2     2
#
# [500000 rows x 23 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder()
all_data_encoded = encoder.fit_transform(all_data)

# %%
num_train = len(train)

X_train = all_data_encoded[:num_train]
X_test = all_data_encoded[num_train:]
y=train['target']

# %%
from sklearn.model_selection import train_test_split

X_train,X_valid,y_train,y_valid = train_test_split(X_train,y,test_size=0.1,stratify=y,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression

logistic_model = LogisticRegression(max_iter=1000,random_state=42)
logistic_model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_preds=logistic_model.predict_proba(X_valid)[:,1]

# %%
logistic_model.predict(X_valid)
# Out:
# array([1, 0, 0, ..., 1, 1, 0])
